# %%
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = yf.download("VDE VAW VIS VCR VDC VHT VFH VGT VOX VPU VNQ", period="2y", interval = "1d")['Adj Close']
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
# Estimated yearly returns for individual ETF
ind_er = df.resample('Y').last().pct_change().mean()
ind_er
# Out:
# VAW    0.232834
# VCR    0.374343
# VDC    0.109568
# VDE    0.143237
# VFH    0.187174
# VGT    0.368837
# VHT    0.174624
# VIS    0.176082
# VNQ    0.135049
# VOX    0.245687
# VPU    0.041107
# dtype: float64

# %%
# Variance for individual ETF
df.resample('Y').last().pct_change().var()
# Out:
# VAW    0.002951
# VCR    0.023869
# VDC    0.000002
# VDE    0.448383
# VFH    0.085508
# VGT    0.016781
# VHT    0.000137
# VIS    0.005547
# VNQ    0.065633
# VOX    0.004143
# VPU    0.004696
# dtype: float64

# %%
# Correlation Coefficient Matrix
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
#           VAW       VCR       VDC       VDE       VFH       VGT       VHT  \
# VAW  1.000000  0.823874  0.776481  0.789243  0.909179  0.745266  0.780413
# VCR  0.823874  1.000000  0.727009  0.650249  0.790121  0.887380  0.791348
# VDC  0.776481  0.727009  1.000000  0.559302  0.751159  0.754895  0.828857
# VDE  0.789243  0.650249  0.559302  1.000000  0.830366  0.545864  0.579841
# VFH  0.909179  0.790121  0.751159  0.830366  1.000000  0.700049  0.744860
# VGT  0.745266  0.887380  0.754895  0.545864  0.700049  1.000000  0.848331
# VHT  0.780413  0.791348  0.828857  0.579841  0.744860  0.848331  1.000000
# VIS  0.939307  0.847323  0.785954  0.804143  0.940553  0.759941  0.792310
# VNQ  0.819467  0.796447  0.792140  0.657030  0.839568  0.732486  0.778689
# VOX  0.762979  0.886614  0.760703  0.607106  0.748434  0.907409  0.813444
# VPU  0.728977  0.647512  0.853102  0.504085  0.723906  0.648173  0.765035
#
#           VIS       VNQ       VOX       VPU
# VAW  0.939307  0.819467  0.762979  0.728977
# VCR  0.847323  0.796447  0.886614  0.647512
# VDC  0.785954  0.792140  0.760703  0.853102
# VDE  0.804143  0.657030  0.607106  0.504085
# VFH  0.940553  0.839568  0.748434  0.723906
# VGT  0.759941  0.732486  0.907409  0.648173
# VHT  0.792310  0.778689  0.813444  0.765035
# VIS  1.000000  0.858558  0.784340  0.743266
# VNQ  0.858558  1.000000  0.758325  0.832023
# VOX  0.784340  0.758325  1.000000  0.661239
# VPU  0.743266  0.832023  0.661239  1.000000

# %%
# VIS, VFH and VOX are now removed due to their high correlation coefficients
df = yf.download("VDE VAW VCR VDC VHT VGT VPU VNQ", period="2y", interval = "1d")['Adj Close']
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
# Covariance Matrix
cov_matrix = df.pct_change().cov()
cov_matrix
# Out:
#           VAW       VCR       VDC       VDE       VGT       VHT       VNQ  \
# VAW  0.000364  0.000270  0.000196  0.000443  0.000274  0.000220  0.000307
# VCR  0.000270  0.000297  0.000165  0.000328  0.000295  0.000201  0.000268
# VDC  0.000196  0.000165  0.000176  0.000216  0.000193  0.000163  0.000207
# VDE  0.000443  0.000328  0.000216  0.000879  0.000308  0.000252  0.000380
# VGT  0.000274  0.000295  0.000193  0.000308  0.000373  0.000243  0.000277
# VHT  0.000220  0.000201  0.000163  0.000252  0.000243  0.000221  0.000226
# VNQ  0.000307  0.000268  0.000207  0.000380  0.000277  0.000226  0.000387
# VPU  0.000255  0.000203  0.000208  0.000271  0.000229  0.000208  0.000300
#
#           VPU
# VAW  0.000255
# VCR  0.000203
# VDC  0.000208
# VDE  0.000271
# VGT  0.000229
# VHT  0.000208
# VNQ  0.000300
# VPU  0.000338

# %%
# Correlation Coefficient Matrix
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
#           VAW       VCR       VDC       VDE       VGT       VHT       VNQ  \
# VAW  1.000000  0.823874  0.776481  0.789243  0.745267  0.780413  0.819467
# VCR  0.823874  1.000000  0.727010  0.650248  0.887380  0.791348  0.796447
# VDC  0.776481  0.727010  1.000000  0.559302  0.754896  0.828858  0.792141
# VDE  0.789243  0.650248  0.559302  1.000000  0.545864  0.579840  0.657030
# VGT  0.745267  0.887380  0.754896  0.545864  1.000000  0.848331  0.732486
# VHT  0.780413  0.791348  0.828858  0.579840  0.848331  1.000000  0.778689
# VNQ  0.819467  0.796447  0.792141  0.657030  0.732486  0.778689  1.000000
# VPU  0.728977  0.647511  0.853102  0.504085  0.648173  0.765035  0.832023
#
#           VPU
# VAW  0.728977
# VCR  0.647511
# VDC  0.853102
# VDE  0.504085
# VGT  0.648173
# VHT  0.765035
# VNQ  0.832023
# VPU  1.000000

# %%
# Estimated yearly returns for individual ETF
ind_er = df.resample('Y').last().pct_change().mean()
ind_er
# Out:
# VAW    0.232834
# VCR    0.374343
# VDC    0.109568
# VDE    0.143237
# VGT    0.368837
# VHT    0.174624
# VNQ    0.135049
# VPU    0.041107
# dtype: float64

# %%
# Variance for individual ETF
df.resample('Y').last().pct_change().var()
# Out:
# VAW    0.002951
# VCR    0.023869
# VDC    0.000002
# VDE    0.448383
# VGT    0.016781
# VHT    0.000137
# VNQ    0.065633
# VPU    0.004696
# dtype: float64

# %%
# Volatility is given by the annual standard deviation. We multiply by 250 because there are 250 trading days/year.
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
ann_sd
# Out:
# VAW    0.303522
# VCR    0.275689
# VDC    0.209727
# VDE    0.473346
# VGT    0.306986
# VHT    0.235887
# VNQ    0.317078
# VPU    0.290528
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#       Returns  Volatility
# VAW  0.232834    0.303522
# VCR  0.374343    0.275689
# VDC  0.109568    0.209727
# VDE  0.143237    0.473346
# VGT  0.368837    0.306986
# VHT  0.174624    0.235887
# VNQ  0.135049    0.317078
# VPU  0.041107    0.290528

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(df.columns)
num_portfolios = 100000

# %%
# Generate the set of minimum variance portfolio
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)
    
data = {'Returns':p_ret, 'Volatility':p_vol}

# %%
for counter, symbol in enumerate(df.columns.tolist()):
    data[symbol+' weight'] = [w[counter] for w in p_weights]
    
portfolios  = pd.DataFrame(data)

# %%
# global minimum variance portfolio
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
min_vol_port
# Out:
# Returns       0.142590
# Volatility    0.220456
# VAW weight    0.043311
# VCR weight    0.095017
# VDC weight    0.641368
# VDE weight    0.042176
# VGT weight    0.004896
# VHT weight    0.059669
# VNQ weight    0.039687
# VPU weight    0.073876
# Name: 73930, dtype: float64

# %%
# global minimum variance portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)

# %%
# tangency portfolio
rf = 0.0017 # risk free rate, from https://www.treasury.gov/resource-center/data-chart-center/interest-rates/Pages/TextView.aspx?data=yield
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns       0.311394
# Volatility    0.266601
# VAW weight    0.129078
# VCR weight    0.269177
# VDC weight    0.037109
# VDE weight    0.016253
# VGT weight    0.418898
# VHT weight    0.097578
# VNQ weight    0.014111
# VPU weight    0.017796
# Name: 18882, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(10, 10))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

# %%
# Sharpe ratio
sharpe_ratio = (optimal_risky_port['Returns']-rf)/optimal_risky_port['Volatility']
sharpe_ratio
# Out:
# 1.1616375080411503
